# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt


# K-modes
import kmodes

# 나무
from sklearn.tree import export_graphviz
import graphviz

# 데이터 분할
from sklearn.model_selection import train_test_split

# 예측 모형: Logistic regression
from sklearn.tree import DecisionTreeClassifier as DTC
from sklearn.ensemble import RandomForestClassifier as RFC
from sklearn.ensemble import GradientBoostingClassifier as GBC

from sklearn.model_selection import GridSearchCV

# 평가 함수
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_curve, auc, f1_score


# https://pypi.org/project/kmodes/
from kmodes.kmodes import KModes

# %matplotlib inline
matplotlib.rc('font', family = 'NanumBarunGothic')

path = '/home/pirl/BDAI-정덕성/Group/Python/'
list_files = ['user.csv', 'address.csv', 'contract.csv']

# %%
df_type1 = pd.read_csv(path + 'pred_type1.csv', engine='python', encoding = 'euc-kr')

# %%
# Out:
#        Unnamed: 0  gender customerType     age  marital  residence  channel  \
# 0               0  FEMALE     PERSONAL     50대   SINGLE  OFFICETEL   서비스 방문
# 1               1  FEMALE     PERSONAL     20대  MARRIED  OFFICETEL    렌탈재계약
# 2               2  FEMALE     PERSONAL     30대  MARRIED  OFFICETEL     렌탈총판
# 3               3    MALE     PERSONAL     20대  MARRIED       ETC.     하이마트
# 4               4    MALE     PERSONAL     30대   SINGLE       ETC.     하이마트
# 5               5  FEMALE     PERSONAL     40대  MARRIED      APART   서비스 방문
# 6               6    MALE     PERSONAL     20대  MARRIED  OFFICETEL   홈쇼핑/방송
# 7               7    MALE     PERSONAL     50대  MARRIED  OFFICETEL   홈쇼핑/방송
# 8               8    MALE     BUSINESS  60대 이상   SINGLE  OFFICETEL  홈쇼핑/인터넷
# 9               9    MALE     PERSONAL     30대  MARRIED      APART      이마트
# 10             10    MALE     PERSONAL     50대  MARRIED      APART   서비스 방문
# 11             11  FEMALE     PERSONAL     50대  MARRIED      HOUSE   서비스 방문
# 12             12    MALE     PERSONAL  60대 이상  MARRIED      HOUSE   홈쇼핑/방송
# 13             13  FEMALE     PERSONAL     50대  MARRIED  OFFICETEL      인터넷
# 14             14  FEMALE     PERSONAL     40대   SINGLE       ETC.    렌탈재계약
# 15             15  FEMALE     PERSONAL     30대  MARRIED  OFFICETEL    렌탈재계약
# 16             16  FEMALE     PERSONAL     30대  MARRIED      HOUSE     하이마트
# 17             17  FEMALE     PERSONAL     40대   SINGLE      HOUSE  홈쇼핑/인터넷
# 18             18  FEMALE     PERSONAL  60대 이상  MARRIED      HOUSE   하하영업방판
# 19             19    MALE     PERSONAL     40대  MARRIED      HOUSE     전자랜드
# 20             20  FEMALE     PERSONAL     30대   SINGLE      APART     홈플러스
# 21             21  FEMALE     PERSONAL     50대   SINGLE      APART     전자랜드
# 22             22    MALE     PERSONAL     50대  MARRIED  OFFICETEL   서비스 방문
# 23             23  FEMALE     PERSONAL     30대  MARRIED      HOUSE      인터넷
# 24             24  FEMALE     PERSONAL     30대   SINGLE  OFFICETEL      이마트
# 25             25    MALE     BUSINESS     50대   SINGLE      APART     하이마트
#
#        credit payment paymentCO  ... contractType contractType_1  \
# 0      MIDDLE    CARD      현대카드  ...          MMQ              M
# 1      MIDDLE     CMS      국민은행  ...          EIQ              E
# 2        HIGH     CMS      기업은행  ...          HIQ              H
# 3      MIDDLE     CMS      국민은행  ...          MIQ              M
# 4      MIDDLE     CMS      기업은행  ...          MMQ              M
# 5         LOW     CMS      국민은행  ...          HMQ              H
# 6        HIGH    CARD      국민카드  ...          MIQ              M
# 7      MIDDLE     CMS      기업은행  ...          MIQ              M
# 8      MIDDLE     CMS      기업은행  ...          MIQ              M
# 9      MIDDLE    CARD      현대카드  ...          MIQ              M
# 10     MIDDLE    CARD      외환카드  ...          MIQ              M
# 11     MIDDLE     CMS     새마을금고  ...          EIQ              E
# 12     MIDDLE    CARD      현대카드  ...          MIQ              M
# 13        LOW     CMS      국민은행  ...          MIQ              M
# 14     MIDDLE    CARD      현대카드  ...          MMQ              M
# 15     MIDDLE    CARD      현대카드  ...          MMQ              M
# 16     MIDDLE    CARD      외환카드  ...          HMQ              H
# 17     MIDDLE    CARD      삼성카드  ...          MMQ              M
# 18       HIGH    CARD      외환카드  ...          EIQ              E
# 19     MIDDLE    CARD      삼성카드  ...          EIQ              E
# 20     MIDDLE     CMS      기업은행  ...          MMQ              M
# 21       HIGH    CARD      삼성카드  ...          MMQ              M
# 22     MIDDLE     CMS    SC제일은행  ...          EIQ              E
# 23     MIDDLE     CMS      우리은행  ...          HMQ              H
# 24     MIDDLE    CARD      현대카드  ...          HIQ              H
# 25     MIDDLE    CARD      국민카드  ...          MIQ              M
# 26     MIDDLE     CMS      우리은행  ...          MMQ              M
# 27       HIGH    CARD      삼성카드  ...          MIQ              M
# 28     MIDDLE     CMS    SC제일은행  ...          HIQ              H
# 29     MIDDLE    CARD      외환카드  ...          EMQ              E
# ...       ...     ...       ...  ...          ...            ...
# 49615  MIDDLE     CMS      국민은행  ...          MMQ              M
# 49616  MIDDLE     CMS      기업은행  ...          EMQ              E
# 49617  MIDDLE    CARD      국민카드  ...          MMQ              M
# 49618  MIDDLE     CMS    SC제일은행  ...          EMQ              E
# 49619    HIGH    CARD      외환카드  ...          HIQ              H
# 49620    HIGH     CMS      우리은행  ...          MIQ              M
# 49621  MIDDLE     CMS      국민은행  ...          MIQ              M
# 49622     LOW    CARD      외환카드  ...          MIQ              M
# 49623  MIDDLE    CARD      외환카드  ...          HMQ              H
# 49624    HIGH     CMS     새마을금고  ...          EIQ              E
# 49625  MIDDLE     CMS      기업은행  ...          EMQ              E
# 49626  MIDDLE     CMS     새마을금고  ...          EMQ              E
# 49627  MIDDLE     CMS      국민은행  ...          MIQ              M
# 49628    HIGH    CARD      삼성카드  ...          EMQ              E
# 49629    HIGH    CARD      롯데카드  ...          MMQ              M
# 49630    HIGH    CARD      국민카드  ...          MIQ              M
# 49631     LOW    CARD      삼성카드  ...          HMQ              H
# 49632    HIGH    CARD      외환카드  ...          MIQ              M
# 49633    HIGH     CMS      우리은행  ...          EIQ              E
# 49634  MIDDLE    CARD      국민카드  ...          EMQ              E
# 49635     LOW     CMS      국민은행  ...          EIQ              E
# 49636  MIDDLE     CMS     새마을금고  ...          EMQ              E
# 49637    HIGH     CMS       우체국  ...          MIQ              M
# 49638  MIDDLE     CMS      우리은행  ...          EIQ              E
# 49639  MIDDLE     CMS      기업은행  ...          MMQ              M
# 49640  MIDDLE    CARD      삼성카드  ...          EMQ              E
# 49641  MIDDLE    CARD      외환카드  ...          MMQ              M
# 49642  MIDDLE     CMS      국민은행  ...          HMQ              H
# 49643    HIGH    CARD      국민카드  ...          MMQ              M
# 49644  MIDDLE     CMS      우리은행  ...          EMQ              E
#
#       contractType_2 cityGradeIS Termination_str maxDay_str maxGift_str  \
# 0                  M         2급지         중도 해약 X        목요일        지급 X
# 1                  I         1급지         중도 해약 X        토요일        지급 O
# 2                  I         1급지         중도 해약 X        화요일        지급 O
# 3                  I         1급지         중도 해약 X        토요일        지급 O
# 4                  M         2급지         중도 해약 X        목요일        지급 O
# 5                  M         2급지         중도 해약 X        일요일        지급 X
# 6                  I         1급지         중도 해약 X        목요일        지급 O
# 7                  I         5급지         중도 해약 X        일요일        지급 X
# 8                  I         1급지         중도 해약 X        화요일        지급 O
# 9                  I         4급지         중도 해약 X        월요일        지급 O
# 10                 I         4급지         중도 해약 X        월요일        지급 O
# 11                 I         1급지         중도 해약 X        일요일        지급 X
# 12                 I         5급지         중도 해약 X        토요일        지급 X
# 13                 I         5급지         중도 해약 X        토요일        지급 O
# 14                 M         3급지         중도 해약 X        일요일        지급 O
# 15                 M         5급지         중도 해약 X        토요일        지급 X
# 16                 M         3급지         중도 해약 X        화요일        지급 O
# 17                 M         1급지         중도 해약 X        금요일        지급 X
# 18                 I         1급지         중도 해약 X        월요일        지급 O
# 19                 I         1급지         중도 해약 X        일요일        지급 O
# 20                 M         6급지         중도 해약 X        금요일        지급 X
# 21                 M         4급지         중도 해약 X        일요일        지급 X
# 22                 I         2급지         중도 해약 X        토요일        지급 O
# 23                 M         3급지         중도 해약 X        월요일        지급 X
# 24                 I         1급지         중도 해약 X        목요일        지급 O
# 25                 I         1급지         중도 해약 X        수요일        지급 X
# 26                 M         2급지         중도 해약 X        일요일        지급 X
# 27                 I         6급지         중도 해약 X        일요일        지급 X
# 28                 I         1급지         중도 해약 X        일요일        지급 O
# 29                 M         3급지         중도 해약 X        일요일        지급 O
# ...              ...         ...             ...        ...         ...
# 49615              M         5급지         중도 해약 X        토요일        지급 O
# 49616              M         2급지         중도 해약 X        월요일        지급 O
# 49617              M         4급지         중도 해약 X        일요일        지급 O
# 49618              M         3급지         중도 해약 X        금요일        지급 O
# 49619              I         3급지         중도 해약 X        월요일        지급 X
# 49620              I         3급지         중도 해약 X        금요일        지급 X
# 49621              I         1급지         중도 해약 X        목요일        지급 O
# 49622              I         4급지         중도 해약 X        토요일        지급 O
# 49623              M         2급지         중도 해약 X        목요일        지급 X
# 49624              I         1급지         중도 해약 X        화요일        지급 O
# 49625              M         3급지         중도 해약 X        금요일        지급 X
# 49626              M         3급지         중도 해약 X        토요일        지급 O
# 49627              I         1급지         중도 해약 X        수요일        지급 O
# 49628              M         2급지         중도 해약 X        목요일        지급 O
# 49629              M         1급지         중도 해약 X        목요일        지급 O
# 49630              I         1급지         중도 해약 X        금요일        지급 X
# 49631              M         2급지         중도 해약 X        월요일        지급 O
# 49632              I         4급지         중도 해약 X        토요일        지급 O
# 49633              I         1급지         중도 해약 X        목요일        지급 O
# 49634              M         2급지         중도 해약 X        일요일        지급 O
# 49635              I         6급지         중도 해약 X        토요일        지급 O
# 49636              M         3급지         중도 해약 X        월요일        지급 O
# 49637              I         1급지         중도 해약 X        월요일        지급 X
# 49638              I         2급지         중도 해약 X        월요일        지급 O
# 49639              M         1급지         중도 해약 X        금요일        지급 O
# 49640              M         4급지         중도 해약 X        일요일        지급 O
# 49641              M         1급지         중도 해약 X        화요일        지급 O
# 49642              M         3급지         중도 해약 X        일요일        지급 O
# 49643              M         3급지         중도 해약 X        일요일        지급 O
# 49644              M         2급지         중도 해약 X        토요일        지급 X
#
#       Termination_rate overDue_str predType_1
# 0                    A          0일          M
# 1                    A          0일          E
# 2                    B          0일          H
# 3                    B          0일          M
# 4                    B          0일          M
# 5                    A          0일          H
# 6                    B          0일          M
# 7                    B          0일          M
# 8                    B          0일          M
# 9                    B          0일          M
# 10                   A          0일          M
# 11                   A          0일          E
# 12                   B          0일          M
# 13                   B          0일          M
# 14                   A          0일          M
# 15                   A          0일          M
# 16                   B          0일          H
# 17                   B          0일          M
# 18                   B          0일          E
# 19                   B          0일          E
# 20                   B          0일          M
# 21                   B          0일          M
# 22                   A          0일          M
# 23                   B          0일          H
# 24                   B          0일          H
# 25                   B          0일          M
# 26                   B          0일          M
# 27                   A          0일          M
# 28                   A          0일          H
# 29                   A          0일          E
# ...                ...         ...        ...
# 49615                B          0일          M
# 49616                B          0일          E
# 49617                A          0일          M
# 49618                B          0일          E
# 49619                A          0일          H
# 49620                B          0일          E
# 49621                B          0일          M
# 49622                B          0일          M
# 49623                B          0일          M
# 49624                A          0일          E
# 49625                A          0일          E
# 49626                B          0일          E
# 49627                A          0일          M
# 49628                B          0일          E
# 49629                B          0일          M
# 49630                B          0일          M
# 49631                B          0일          H
# 49632                B          0일          M
# 49633                B          0일          E
# 49634                B          0일          E
# 49635                B          0일          M
# 49636                B          0일          E
# 49637                A          0일          M
# 49638                B          0일          E
# 49639                B          0일          M
# 49640                B          0일          M
# 49641                B          0일          M
# 49642                B          0일          M
# 49643                B          0일          M
# 49644                B          0일          E
#
# [49645 rows x 25 columns]
