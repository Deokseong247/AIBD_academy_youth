# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt


# K-modes
import kmodes

# 나무
from sklearn.tree import export_graphviz
import graphviz

# 데이터 분할
from sklearn.model_selection import train_test_split

# 예측 모형: Logistic regression
from sklearn.tree import DecisionTreeClassifier as DTC
from sklearn.ensemble import RandomForestClassifier as RFC
from sklearn.ensemble import GradientBoostingClassifier as GBC

from sklearn.model_selection import GridSearchCV

# 평가 함수
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_curve, auc


# https://pypi.org/project/kmodes/
from kmodes.kmodes import KModes

# %matplotlib inline
matplotlib.rc('font', family = 'NanumBarunGothic')

path = '/home/pirl/BDAI-정덕성/Group/Python/'
list_files = ['user.csv', 'address.csv', 'contract.csv']

# %%
df = pd.read_csv(path + 'merged_final.csv', engine='python', encoding = 'euc-kr')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49645 entries, 0 to 49644
# Data columns (total 23 columns):
# gender              49645 non-null object
# customerType        49645 non-null object
# age                 49645 non-null object
# marital             49645 non-null object
# residence           49645 non-null object
# channel             49645 non-null object
# credit              49645 non-null object
# payment             49645 non-null object
# paymentCO           49645 non-null object
# province            49645 non-null object
# provinceIS          49645 non-null object
# cityGrade           49645 non-null object
# channelType         49645 non-null object
# contractExtended    49645 non-null object
# contractType        49645 non-null object
# contractType_1      49645 non-null object
# contractType_2      49645 non-null object
# cityGradeIS         49645 non-null object
# Termination_str     49645 non-null object
# maxDay_str          49645 non-null object
# maxGift_str         49645 non-null object
# Termination_rate    49645 non-null object
# overDue_str         49645 non-null object
# dtypes: object(23)
# memory usage: 8.7+ MB

# %% [markdown]
# ## X & Y 분리

# %%
df_tree = df.drop(['channel', # channelType 사용
                   'credit', 'payment', 'paymentCO', # 경향성 없음
                   'province', 'cityGrade', # 실거주지 정보 제외
                   'contractExtended', 'Termination_str', 
                   'Termination_rate', # 목표변수 파생변수 제외
                   'contractType_1', 'contractType_2', # 6개 범주 사용
                   'maxDay_str', 'overDue_str'], axis=1) # 경향성 없음             
                                  
# X, Y 분리 & Dummy 변수
df_tree_y = pd.get_dummies(df_tree[['contractType']], drop_first=True)
df_tree_x = pd.get_dummies(df_tree.drop('contractType', axis=1))
df_tree_x_short = pd.get_dummies(df_tree.drop('contractType', axis=1),
                                 drop_first = True)

# %%
df_tree_x_short.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49645 entries, 0 to 49644
# Data columns (total 30 columns):
# gender_MALE              49645 non-null uint8
# customerType_PERSONAL    49645 non-null uint8
# age_30대                  49645 non-null uint8
# age_40대                  49645 non-null uint8
# age_50대                  49645 non-null uint8
# age_60대 이상               49645 non-null uint8
# marital_SINGLE           49645 non-null uint8
# residence_ETC.           49645 non-null uint8
# residence_HOUSE          49645 non-null uint8
# residence_OFFICETEL      49645 non-null uint8
# provinceIS_경상도           49645 non-null uint8
# provinceIS_부산시           49645 non-null uint8
# provinceIS_서울시           49645 non-null uint8
# provinceIS_전라도           49645 non-null uint8
# provinceIS_충청도           49645 non-null uint8
# channelType_쇼핑몰          49645 non-null uint8
# channelType_양판점          49645 non-null uint8
# channelType_연장           49645 non-null uint8
# channelType_총판           49645 non-null uint8
# contractType_EMQ         49645 non-null uint8
# contractType_HIQ         49645 non-null uint8
# contractType_HMQ         49645 non-null uint8
# contractType_MIQ         49645 non-null uint8
# contractType_MMQ         49645 non-null uint8
# cityGradeIS_2급지          49645 non-null uint8
# cityGradeIS_3급지          49645 non-null uint8
# cityGradeIS_4급지          49645 non-null uint8
# cityGradeIS_5급지          49645 non-null uint8
# cityGradeIS_6급지          49645 non-null uint8
# maxGift_str_지급 X         49645 non-null uint8
# dtypes: uint8(30)
# memory usage: 1.4 MB

# %%
# 나무 데이터
df_train_s, df_test_s, df_train_y, df_test_y = train_test_split(df_tree_x_short, df_tree_y, test_size = 0.3)

print('train data X size:{}'.format(df_train_s.shape))
print('train data Y size:{}'.format(df_train_y.shape))
print('test data X size:{}'.format(df_test_s.shape))
print('test data Y size:{}'.format(df_test_y.shape))
# Out:
# train data X size:(34751, 30)
# train data Y size:(34751, 1)
# test data X size:(14894, 30)
# test data Y size:(14894, 1)

# %% [markdown]
# ### 기본 나무 점수

# %%
tree_final = DTC()
tree_final.fit(df_train_s, df_train_y)
y_pred = tree_final.predict(df_test_s)

# 예측 정확도 (AUC)
false_positive_rate, true_positive_rate, thresholds = roc_curve(df_test_y, y_pred)
roc_auc = auc(false_positive_rate, true_positive_rate)
roc_auc.round(3)
# Out:
# 0.648

# %%
params = {'max_depth':'',
          'min_samples_leaf':'',
          'min_samples_split':'',
          'max_features': ''}

# %% [markdown]
# ### 최대 깊이

# %%
# Train/Test Score 저장할 list
train_results = []; test_results = []

# max_depth
para_depth = [depth for depth in range(15, 31)]


for v_max_depth in para_depth:
    tree = DTC(max_depth = v_max_depth)
    tree.fit(df_train_s, df_train_y)
    
    # Train Fit
    train_pred = tree.predict(df_train_s)
    false_positive_rate, true_positive_rate, thresholds = roc_curve(df_train_y, train_pred)
    roc_auc = auc(false_positive_rate, true_positive_rate)
    
    # Add auc score to previous train results
    train_results.append(roc_auc)

    # Test Fit
    test_pred = tree.predict(df_test_s)
    false_positive_rate, true_positive_rate, thresholds = roc_curve(df_test_y, test_pred)
    roc_auc = auc(false_positive_rate, true_positive_rate)
    
    # Add auc score to previous test results
    test_results.append(roc_auc)
    
    
df_score_depth = pd.DataFrame({'Depth': para_depth,
                               'TrainScore': train_results,
                               'TestScore': test_results})

plt.plot(para_depth, train_results, linestyle='-', label="Train Score")
plt.plot(para_depth, test_results, linestyle='--', label="Test Score")

plt.legend()

df_score_depth.round(3)
# Out:
#     Depth  TrainScore  TestScore
# 0      15       0.800      0.629
# 1      16       0.832      0.632
# 2      17       0.852      0.635
# 3      18       0.870      0.640
# 4      19       0.885      0.641
# 5      20       0.901      0.647
# 6      21       0.909      0.644
# 7      22       0.915      0.648
# 8      23       0.917      0.648
# 9      24       0.919      0.649
# 10     25       0.920      0.647
# 11     26       0.920      0.650
# 12     27       0.920      0.646
# 13     28       0.920      0.649
# 14     29       0.920      0.650
# 15     30       0.920      0.645

# %% [markdown]
# ### 최대 깊이 = 26

# %%
params['max_depth'] = 26

# %% [markdown]
# ### 최소 분리노드 크기

# %%
# Train/Test Score 저장할 list
train_results = []; test_results = []

# max_split
para_split = [split*2 for split in range(2, 31)]


for v_max_split in para_split:
    tree = DTC(# max_depth = params['max_depth'],
               min_samples_split = v_max_split)
    
    tree.fit(df_train_s, df_train_y)
    
    # Train Fit
    train_pred = tree.predict(df_train_s)
    false_positive_rate, true_positive_rate, thresholds = roc_curve(df_train_y, train_pred)
    roc_auc = auc(false_positive_rate, true_positive_rate)
    
    # Add auc score to previous train results
    train_results.append(roc_auc)

    # Test Fit
    test_pred = tree.predict(df_test_s)
    false_positive_rate, true_positive_rate, thresholds = roc_curve(df_test_y, test_pred)
    roc_auc = auc(false_positive_rate, true_positive_rate)
    
    # Add auc score to previous test results
    test_results.append(roc_auc)
    
    
df_score_split = pd.DataFrame({'split': para_split,
                               'TrainScore': train_results,
                               'TestScore': test_results})

plt.plot(para_split, train_results, linestyle='-', label="Train Score")
plt.plot(para_split, test_results, linestyle='--', label="Test Score")

plt.legend()

df_score_split.round(3)
# Out:
#     split  TrainScore  TestScore
# 0       4       0.864      0.649
# 1       6       0.819      0.647
# 2       8       0.783      0.635
# 3      10       0.753      0.627
# 4      12       0.730      0.624
# 5      14       0.714      0.618
# 6      16       0.687      0.605
# 7      18       0.667      0.598
# 8      20       0.657      0.597
# 9      22       0.648      0.594
# 10     24       0.642      0.591
# 11     26       0.638      0.593
# 12     28       0.630      0.591
# 13     30       0.619      0.585
# 14     32       0.608      0.582
# 15     34       0.605      0.580
# 16     36       0.603      0.579
# 17     38       0.596      0.576
# 18     40       0.594      0.577
# 19     42       0.594      0.577
# 20     44       0.593      0.577
# 21     46       0.591      0.577
# 22     48       0.588      0.575
# 23     50       0.585      0.573
# 24     52       0.584      0.573
# 25     54       0.580      0.570
# 26     56       0.579      0.570
# 27     58       0.576      0.568
# 28     60       0.568      0.559

# %%
params['min_samples_split'] = 4

# %% [markdown]
# ### 최소 최종노드 크기

# %%
# Train/Test Score 저장할 list
train_results = []; test_results = []

# max_leaf
para_leaf = [leaf for leaf in range(1, 31)]


for v_max_leaf in para_leaf:
    tree = DTC(max_depth = params['max_depth'],
               min_samples_leaf = v_max_leaf)
    
    tree.fit(df_train_s, df_train_y)
    
    # Train Fit
    train_pred = tree.predict(df_train_s)
    false_positive_rate, true_positive_rate, thresholds = roc_curve(df_train_y, train_pred)
    roc_auc = auc(false_positive_rate, true_positive_rate)
    
    # Add auc score to previous train results
    train_results.append(roc_auc)

    # Test Fit
    test_pred = tree.predict(df_test_s)
    false_positive_rate, true_positive_rate, thresholds = roc_curve(df_test_y, test_pred)
    roc_auc = auc(false_positive_rate, true_positive_rate)
    
    # Add auc score to previous test results
    test_results.append(roc_auc)
    
    
df_score_leaf = pd.DataFrame({'leaf': para_leaf,
                               'TrainScore': train_results,
                               'TestScore': test_results})

plt.plot(para_leaf, train_results, linestyle='-', label="Train Score")
plt.plot(para_leaf, test_results, linestyle='--', label="Test Score")

plt.legend()

df_score_leaf.round(3)
# Out:
#     leaf  TrainScore  TestScore
# 0      1       0.920      0.645
# 1      2       0.856      0.652
# 2      3       0.753      0.624
# 3      4       0.717      0.624
# 4      5       0.665      0.598
# 5      6       0.660      0.598
# 6      7       0.640      0.588
# 7      8       0.626      0.589
# 8      9       0.614      0.585
# 9     10       0.605      0.577
# 10    11       0.595      0.573
# 11    12       0.591      0.571
# 12    13       0.594      0.576
# 13    14       0.590      0.572
# 14    15       0.586      0.575
# 15    16       0.576      0.566
# 16    17       0.572      0.562
# 17    18       0.572      0.562
# 18    19       0.572      0.562
# 19    20       0.566      0.559
# 20    21       0.564      0.557
# 21    22       0.564      0.557
# 22    23       0.564      0.557
# 23    24       0.560      0.552
# 24    25       0.554      0.550
# 25    26       0.554      0.550
# 26    27       0.554      0.550
# 27    28       0.547      0.542
# 28    29       0.543      0.537
# 29    30       0.543      0.537

# %%
params['min_samples_leaf'] = 2

# %% [markdown]
# ### 최대 변수

# %%
# Train/Test Score 저장할 list
train_results = []; test_results = []

# max_feature
para_feature = [feature for feature in range(1,df_train_s.shape[1])]


for v_max_feature in para_feature:
    tree = DTC(# max_depth = params['max_depth'],
               max_features = v_max_feature)
    
    tree.fit(df_train_s, df_train_y)
    
    # Train Fit
    train_pred = tree.predict(df_train_s)
    false_positive_rate, true_positive_rate, thresholds = roc_curve(df_train_y, train_pred)
    roc_auc = auc(false_positive_rate, true_positive_rate)
    
    # Add auc score to previous train results
    train_results.append(roc_auc)

    # Test Fit
    test_pred = tree.predict(df_test_s)
    false_positive_rate, true_positive_rate, thresholds = roc_curve(df_test_y, test_pred)
    roc_auc = auc(false_positive_rate, true_positive_rate)
    
    # Add auc score to previous test results
    test_results.append(roc_auc)
    
    
df_score_feature = pd.DataFrame({'feature': para_feature,
                               'TrainScore': train_results,
                               'TestScore': test_results})

plt.plot(para_feature, train_results, linestyle='-', label="Train Score")
plt.plot(para_feature, test_results, linestyle='--', label="Test Score")

plt.legend()

df_score_feature.round(3)
# Out:
#     feature  TrainScore  TestScore
# 0         1        0.92      0.614
# 1         2        0.92      0.609
# 2         3        0.92      0.626
# 3         4        0.92      0.634
# 4         5        0.92      0.625
# 5         6        0.92      0.638
# 6         7        0.92      0.641
# 7         8        0.92      0.643
# 8         9        0.92      0.649
# 9        10        0.92      0.638
# 10       11        0.92      0.647
# 11       12        0.92      0.633
# 12       13        0.92      0.637
# 13       14        0.92      0.638
# 14       15        0.92      0.641
# 15       16        0.92      0.633
# 16       17        0.92      0.640
# 17       18        0.92      0.643
# 18       19        0.92      0.643
# 19       20        0.92      0.635
# 20       21        0.92      0.650
# 21       22        0.92      0.650
# 22       23        0.92      0.649
# 23       24        0.92      0.646
# 24       25        0.92      0.649
# 25       26        0.92      0.651
# 26       27        0.92      0.654
# 27       28        0.92      0.648
# 28       29        0.92      0.648

# %%
params['max_features'] = 27

# %% [markdown]
# ## 최종 나무

# %%
dt_final = DTC(max_depth = params['max_depth'],
               min_samples_leaf = params['min_samples_leaf'],
               min_samples_split = params['min_samples_split'],
               max_features = params['max_features'])

dt_final.fit(df_train_s, df_train_y)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=26,
#                        max_features=27, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=2, min_samples_split=4,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')

# %%
y_pred = dt_final.predict(df_test_s)

# AUC
false_positive_rate, true_positive_rate, thresholds = roc_curve(df_test_y, y_pred)
roc_auc = auc(false_positive_rate, true_positive_rate)

print('AUC: {0:.3f}\n'.format(roc_auc))
print('Accuracy: {0:.3f}\n'.format(accuracy_score(df_test_y, y_pred)))
print('Confusion Mat:\n{}'.format(confusion_matrix(df_test_y, y_pred)))
# Out:
# AUC: 0.646
#
# Accuracy: 0.937
#
# Confusion Mat:
# [[  193   392]
#  [  543 13766]]

# %% [markdown]
# # 랜덤포레스트

# %%
rf_uncustomized = RFC()
rf_uncustomized.fit(df_train_x, df_train_y)
# Out:
# /home/pirl/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=10,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
print('Accuracy on Training: {0:.3f}\n'.format(rf_uncustomized.score(df_train_x, df_train_y)))
print('Accuracy on Test: {0:.3f}\n'.format(rf_uncustomized.score(df_test_x, df_test_y)))
# Out:
# Accuracy on Training: 0.997
#
# Accuracy on Test: 0.958

# %% [markdown]
# ### 숲의 나무 수

# %%
# Train/Test Score 저장할 list
train_accuracy = []; test_accuracy = []

# ntree
para_ntree = [10*ntree for ntree in range(1, 11)]


for v_ntree in para_ntree:
    rf = RFC(n_estimators = v_ntree)
    rf.fit(df_train_x, df_train_y)
    train_accuracy.append(rf.score(df_train_x, df_train_y))
    test_accuracy.append(rf.score(df_test_x, df_test_y))
    
    
df_score_ntree = pd.DataFrame({'N_Tree': para_ntree,
                             'TrainScore': train_accuracy,
                             'TestScore': test_accuracy})

plt.plot(para_ntree, train_accuracy, linestyle='-', label="Train Score")
plt.plot(para_ntree, test_accuracy, linestyle='--', label="Test Score")
plt.legend()

df_score_ntree.round(3)
# Out:
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # Remove the CWD from sys.path while we load stuff.
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # Remove the CWD from sys.path while we load stuff.
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # Remove the CWD from sys.path while we load stuff.
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # Remove the CWD from sys.path while we load stuff.
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # Remove the CWD from sys.path while we load stuff.
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # Remove the CWD from sys.path while we load stuff.
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # Remove the CWD from sys.path while we load stuff.
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # Remove the CWD from sys.path while we load stuff.
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # Remove the CWD from sys.path while we load stuff.
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # Remove the CWD from sys.path while we load stuff.
#    N_Tree  TrainScore  TestScore
# 0      10       0.997      0.958
# 1      20       0.999      0.959
# 2      30       0.999      0.960
# 3      40       0.999      0.961
# 4      50       0.999      0.961
# 5      60       0.999      0.960
# 6      70       0.999      0.961
# 7      80       0.999      0.961
# 8      90       0.999      0.961
# 9     100       0.999      0.962

# %% [markdown]
# ### 나무의 최대 깊이

# %%
# Train/Test Score 저장할 list
train_accuracy = []; test_accuracy = []

# max_depth
para_depth = [depth for depth in range(1, 31)]


for v_max_depth in para_depth:
    rf = RFC(n_estimators = 100,
             max_depth = v_max_depth)
    rf.fit(df_train_x, df_train_y)
    train_accuracy.append(rf.score(df_train_x, df_train_y))
    test_accuracy.append(rf.score(df_test_x, df_test_y))
    
    
df_score_depth = pd.DataFrame({'Depth': para_depth,
                             'TrainScore': train_accuracy,
                             'TestScore': test_accuracy})

plt.plot(para_depth, train_accuracy, linestyle='-', label="Train Score")
plt.plot(para_depth, test_accuracy, linestyle='--', label="Test Score")
plt.legend()

df_score_depth.round(3)
# Out:
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # This is added back by InteractiveShellApp.init_path()
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # This is added back by InteractiveShellApp.init_path()
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # This is added back by InteractiveShellApp.init_path()
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # This is added back by InteractiveShellApp.init_path()
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # This is added back by InteractiveShellApp.init_path()
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # This is added back by InteractiveShellApp.init_path()
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # This is added back by InteractiveShellApp.init_path()
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # This is added back by InteractiveShellApp.init_path()
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # This is added back by InteractiveShellApp.init_path()
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # This is added back by InteractiveShellApp.init_path()
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # This is added back by InteractiveShellApp.init_path()
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # This is added back by InteractiveShellApp.init_path()
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # This is added back by InteractiveShellApp.init_path()
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # This is added back by InteractiveShellApp.init_path()
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # This is added back by InteractiveShellApp.init_path()
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # This is added back by InteractiveShellApp.init_path()
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # This is added back by InteractiveShellApp.init_path()
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # This is added back by InteractiveShellApp.init_path()
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # This is added back by InteractiveShellApp.init_path()
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # This is added back by InteractiveShellApp.init_path()
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # This is added back by InteractiveShellApp.init_path()
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # This is added back by InteractiveShellApp.init_path()
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # This is added back by InteractiveShellApp.init_path()
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # This is added back by InteractiveShellApp.init_path()
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # This is added back by InteractiveShellApp.init_path()
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # This is added back by InteractiveShellApp.init_path()
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # This is added back by InteractiveShellApp.init_path()
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # This is added back by InteractiveShellApp.init_path()
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # This is added back by InteractiveShellApp.init_path()
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # This is added back by InteractiveShellApp.init_path()
#     Depth  TrainScore  TestScore
# 0       1       0.959      0.956
# 1       2       0.959      0.956
# 2       3       0.959      0.956
# 3       4       0.959      0.956
# 4       5       0.959      0.956
# 5       6       0.959      0.956
# 6       7       0.959      0.956
# 7       8       0.960      0.958
# 8       9       0.961      0.959
# 9      10       0.962      0.959
# 10     11       0.964      0.959
# 11     12       0.967      0.960
# 12     13       0.971      0.960
# 13     14       0.975      0.960
# 14     15       0.980      0.961
# 15     16       0.983      0.961
# 16     17       0.988      0.962
# 17     18       0.993      0.961
# 18     19       0.996      0.961
# 19     20       0.998      0.961
# 20     21       0.999      0.961
# 21     22       0.999      0.961
# 22     23       0.999      0.961
# 23     24       0.999      0.961
# 24     25       0.999      0.962
# 25     26       0.999      0.961
# 26     27       0.999      0.961
# 27     28       0.999      0.961
# 28     29       0.999      0.962
# 29     30       0.999      0.961

# %% [markdown]
# ### 최소 잎사귀 크기

# %%
# Train/Test Score 저장할 list
train_accuracy = []; test_accuracy = []

# max_depth
para_leaf = [leaf*10 for leaf in range(1, 11)]


for v_leaf in para_leaf:
    rf = RFC(n_estimators = 100,
             max_depth = 25,
             min_samples_leaf = v_leaf)
    rf.fit(df_train_x, df_train_y)
    train_accuracy.append(rf.score(df_train_x, df_train_y))
    test_accuracy.append(rf.score(df_test_x, df_test_y))
    
    
df_score_leaf = pd.DataFrame({'MinLeafSize': para_leaf,
                             'TrainScore': train_accuracy,
                             'TestScore': test_accuracy})


plt.plot(para_leaf, train_accuracy, linestyle='-', label="Train Accuracy")
plt.plot(para_leaf, test_accuracy, linestyle='--', label="Test Accuracy")
plt.legend()
df_score_leaf.round(3)
# Out:
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   if sys.path[0] == '':
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   if sys.path[0] == '':
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   if sys.path[0] == '':
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   if sys.path[0] == '':
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   if sys.path[0] == '':
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   if sys.path[0] == '':
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   if sys.path[0] == '':
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   if sys.path[0] == '':
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   if sys.path[0] == '':
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   if sys.path[0] == '':
#    MinLeafSize  TrainScore  TestScore
# 0           10       0.961      0.959
# 1           20       0.961      0.959
# 2           30       0.960      0.958
# 3           40       0.960      0.957
# 4           50       0.959      0.956
# 5           60       0.959      0.956
# 6           70       0.959      0.956
# 7           80       0.959      0.956
# 8           90       0.959      0.956
# 9          100       0.959      0.956

# %%
# Train/Test Score 저장할 list
train_accuracy = []; test_accuracy = []

# max_depth
para_leaf = [leaf for leaf in range(1, 11)]


for v_leaf in para_leaf:
    rf = RFC(n_estimators = 100,
             max_depth = 25,
             min_samples_leaf = v_leaf)
    rf.fit(df_train_x, df_train_y)
    train_accuracy.append(rf.score(df_train_x, df_train_y))
    test_accuracy.append(rf.score(df_test_x, df_test_y))
    
    
df_score_leaf = pd.DataFrame({'MinLeafSize': para_leaf,
                             'TrainScore': train_accuracy,
                             'TestScore': test_accuracy})


plt.plot(para_leaf, train_accuracy, linestyle='-', label="Train Accuracy")
plt.plot(para_leaf, test_accuracy, linestyle='--', label="Test Accuracy")
plt.legend()
df_score_leaf.round(3)
# Out:
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   if sys.path[0] == '':
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   if sys.path[0] == '':
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   if sys.path[0] == '':
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   if sys.path[0] == '':
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   if sys.path[0] == '':
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   if sys.path[0] == '':
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   if sys.path[0] == '':
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   if sys.path[0] == '':
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   if sys.path[0] == '':
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   if sys.path[0] == '':
#    MinLeafSize  TrainScore  TestScore
# 0            1       0.999      0.961
# 1            2       0.974      0.961
# 2            3       0.970      0.960
# 3            4       0.965      0.960
# 4            5       0.964      0.959
# 5            6       0.963      0.959
# 6            7       0.962      0.959
# 7            8       0.962      0.959
# 8            9       0.962      0.959
# 9           10       0.961      0.959

# %%
rf_final = RFC(n_estimators = 100,
               max_depth = 25)
rf_final.fit(df_train_x, df_train_y)
# Out:
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   This is separate from the ipykernel package so we can avoid doing imports until
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=25, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
y_pred = rf_final.predict(df_test_x)
print('Accuracy: {0:.3f}\n'.format(accuracy_score(df_test_y, y_pred)))
print('Confusion Mat:\n{}'.format(confusion_matrix(df_test_y, y_pred)))
# Out:
# Accuracy: 0.961
#
# Confusion Mat:
# [[  105   545]
#  [   42 14202]]

# %%
df_importance = pd.DataFrame()
df_importance['Feature'] = v_feature_name
df_importance['Importance'] = rf_final.feature_importances_ # TREECLASS.feature_importances_

df_importance.sort_values('Importance', ascending=False, inplace=True)
df_importance.round(3)
# Out:
#                   Feature  Importance
# 3   customerType_PERSONAL       0.043
# 2   customerType_BUSINESS       0.042
# 42         channelType_총판       0.040
# 67         maxDay_str_토요일       0.030
# 4                 age_20대       0.027
# 5                 age_30대       0.026
# 6                 age_40대       0.026
# 66         maxDay_str_일요일       0.025
# 11        residence_APART       0.022
# 17          credit_MIDDLE       0.021
# 18           payment_CARD       0.021
# 7                 age_50대       0.021
# 19            payment_CMS       0.021
# 15            credit_HIGH       0.020
# 14    residence_OFFICETEL       0.019
# 13        residence_HOUSE       0.018
# 10         marital_SINGLE       0.018
# 23           province_서울시       0.018
# 22           province_부산시       0.017
# 29         provinceIS_서울시       0.017
# 0           gender_FEMALE       0.017
# 9         marital_MARRIED       0.017
# 1             gender_MALE       0.017
# 69       maxGift_str_지급 O       0.016
# 28         provinceIS_부산시       0.016
# 70       maxGift_str_지급 X       0.016
# 65         maxDay_str_월요일       0.015
# 68         maxDay_str_화요일       0.014
# 57        cityGradeIS_2급지       0.014
# 39        channelType_쇼핑몰       0.013
# ..                    ...         ...
# 56        cityGradeIS_1급지       0.010
# 12         residence_ETC.       0.008
# 34          cityGrade_3급지       0.008
# 58        cityGradeIS_3급지       0.008
# 43    contractExtended_신규       0.007
# 44    contractExtended_연장       0.007
# 35          cityGrade_4급지       0.007
# 41         channelType_연장       0.007
# 51       contractType_1_E       0.006
# 59        cityGradeIS_4급지       0.006
# 53       contractType_1_M       0.006
# 24           province_전라도       0.006
# 36          cityGrade_5급지       0.006
# 48       contractType_HMQ       0.006
# 50       contractType_MMQ       0.006
# 55       contractType_2_M       0.005
# 30         provinceIS_전라도       0.005
# 54       contractType_2_I       0.005
# 60        cityGradeIS_5급지       0.005
# 71         overDue_str_0일       0.004
# 49       contractType_MIQ       0.004
# 37          cityGrade_6급지       0.004
# 47       contractType_HIQ       0.004
# 46       contractType_EMQ       0.004
# 61        cityGradeIS_6급지       0.004
# 45       contractType_EIQ       0.004
# 75         overDue_str_4일       0.002
# 74         overDue_str_3일       0.002
# 73         overDue_str_2일       0.002
# 72         overDue_str_1일       0.001
#
# [76 rows x 2 columns]

# %%
df_importance.sort_values('Importance', ascending=True, inplace=True)
coordinates=range(len(df_importance))
plt.figure(figsize=(10,20))

plt.barh(y=coordinates, width=df_importance['Importance'])
plt.yticks(coordinates, df_importance['Feature'])
plt.xlabel('변수 중요도')
plt.ylabel('변수')
# Out:
# Text(0, 0.5, '변수')

# %% [markdown]
# ## Dummy Coded Train Set

# %%
# 나무 데이터
df_train_s, df_test_s, df_train_y, df_test_y = train_test_split(df_tree_x_short, df_tree_y, test_size = 0.3)

print('train data X size:{}'.format(df_train_x.shape))
print('train data Y size:{}'.format(df_train_y.shape))
print('test data X size:{}'.format(df_test_x.shape))
print('test data Y size:{}'.format(df_test_y.shape))
# Out:
# train data X size:(34751, 76)
# train data Y size:(34751, 1)
# test data X size:(14894, 76)
# test data Y size:(14894, 1)

# %%
rf_uncustomized = RFC()
rf_uncustomized.fit(df_train_s, df_train_y)
# Out:
# /home/pirl/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=10,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %% [markdown]
# ### 숲의 나무의 수

# %%
# Train/Test Score 저장할 list
train_accuracy = []; test_accuracy = []

# ntree
para_ntree = [10*ntree for ntree in range(1, 16)]


for v_ntree in para_ntree:
    rf = RFC(n_estimators = v_ntree)
    rf.fit(df_train_s, df_train_y)
    train_accuracy.append(rf.score(df_train_s, df_train_y))
    test_accuracy.append(rf.score(df_test_s, df_test_y))
    
    
df_score_ntree = pd.DataFrame({'N_Tree': para_ntree,
                             'TrainScore': train_accuracy,
                             'TestScore': test_accuracy})

plt.plot(para_ntree, train_accuracy, linestyle='-', label="Train Score")
plt.plot(para_ntree, test_accuracy, linestyle='--', label="Test Score")
plt.legend()

df_score_ntree.round(3)
# Out:
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # Remove the CWD from sys.path while we load stuff.
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # Remove the CWD from sys.path while we load stuff.
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # Remove the CWD from sys.path while we load stuff.
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # Remove the CWD from sys.path while we load stuff.
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # Remove the CWD from sys.path while we load stuff.
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # Remove the CWD from sys.path while we load stuff.
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # Remove the CWD from sys.path while we load stuff.
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # Remove the CWD from sys.path while we load stuff.
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # Remove the CWD from sys.path while we load stuff.
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # Remove the CWD from sys.path while we load stuff.
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # Remove the CWD from sys.path while we load stuff.
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # Remove the CWD from sys.path while we load stuff.
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # Remove the CWD from sys.path while we load stuff.
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # Remove the CWD from sys.path while we load stuff.
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # Remove the CWD from sys.path while we load stuff.
#     N_Tree  TrainScore  TestScore
# 0       10       0.998      0.959
# 1       20       0.999      0.962
# 2       30       0.999      0.961
# 3       40       0.999      0.961
# 4       50       0.999      0.961
# 5       60       0.999      0.962
# 6       70       0.999      0.961
# 7       80       0.999      0.961
# 8       90       0.999      0.962
# 9      100       0.999      0.961
# 10     110       0.999      0.961
# 11     120       0.999      0.962
# 12     130       0.999      0.962
# 13     140       0.999      0.962
# 14     150       0.999      0.961

# %% [markdown]
# ### 나무의 최대 깊이

# %%
# Train/Test Score 저장할 list
train_accuracy = []; test_accuracy = []

# max_depth
para_depth = [depth for depth in range(1, 31)]


for v_max_depth in para_depth:
    rf = RFC(n_estimators = 60,
             max_depth = v_max_depth)
    rf.fit(df_train_s, df_train_y)
    train_accuracy.append(rf.score(df_train_s, df_train_y))
    test_accuracy.append(rf.score(df_test_s, df_test_y))
    
    
df_score_depth = pd.DataFrame({'Depth': para_depth,
                             'TrainScore': train_accuracy,
                             'TestScore': test_accuracy})

plt.plot(para_depth, train_accuracy, linestyle='-', label="Train Score")
plt.plot(para_depth, test_accuracy, linestyle='--', label="Test Score")
plt.legend()

df_score_depth.round(3)
# Out:
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # This is added back by InteractiveShellApp.init_path()
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # This is added back by InteractiveShellApp.init_path()
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # This is added back by InteractiveShellApp.init_path()
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # This is added back by InteractiveShellApp.init_path()
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # This is added back by InteractiveShellApp.init_path()
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # This is added back by InteractiveShellApp.init_path()
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # This is added back by InteractiveShellApp.init_path()
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # This is added back by InteractiveShellApp.init_path()
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # This is added back by InteractiveShellApp.init_path()
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # This is added back by InteractiveShellApp.init_path()
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # This is added back by InteractiveShellApp.init_path()
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # This is added back by InteractiveShellApp.init_path()
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # This is added back by InteractiveShellApp.init_path()
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # This is added back by InteractiveShellApp.init_path()
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # This is added back by InteractiveShellApp.init_path()
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # This is added back by InteractiveShellApp.init_path()
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # This is added back by InteractiveShellApp.init_path()
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # This is added back by InteractiveShellApp.init_path()
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # This is added back by InteractiveShellApp.init_path()
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # This is added back by InteractiveShellApp.init_path()
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # This is added back by InteractiveShellApp.init_path()
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # This is added back by InteractiveShellApp.init_path()
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # This is added back by InteractiveShellApp.init_path()
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # This is added back by InteractiveShellApp.init_path()
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # This is added back by InteractiveShellApp.init_path()
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # This is added back by InteractiveShellApp.init_path()
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # This is added back by InteractiveShellApp.init_path()
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # This is added back by InteractiveShellApp.init_path()
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # This is added back by InteractiveShellApp.init_path()
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # This is added back by InteractiveShellApp.init_path()
#     Depth  TrainScore  TestScore
# 0       1       0.958      0.957
# 1       2       0.958      0.957
# 2       3       0.958      0.957
# 3       4       0.958      0.957
# 4       5       0.958      0.957
# 5       6       0.958      0.957
# 6       7       0.958      0.957
# 7       8       0.959      0.957
# 8       9       0.960      0.959
# 9      10       0.961      0.960
# 10     11       0.962      0.960
# 11     12       0.963      0.960
# 12     13       0.967      0.960
# 13     14       0.970      0.961
# 14     15       0.974      0.961
# 15     16       0.979      0.961
# 16     17       0.982      0.961
# 17     18       0.988      0.961
# 18     19       0.991      0.961
# 19     20       0.995      0.962
# 20     21       0.997      0.961
# 21     22       0.998      0.961
# 22     23       0.999      0.962
# 23     24       0.999      0.961
# 24     25       0.999      0.961
# 25     26       0.999      0.962
# 26     27       0.999      0.962
# 27     28       0.999      0.961
# 28     29       0.999      0.962
# 29     30       0.999      0.962

# %% [markdown]
# ### 잎사귀의 최소 크기

# %%
# Train/Test Score 저장할 list
train_accuracy = []; test_accuracy = []

# max_depth
para_leaf = [leaf*10 for leaf in range(1, 11)]


for v_leaf in para_leaf:
    rf = RFC(n_estimators = 60,
             max_depth = 20,
             min_samples_leaf = v_leaf)
    rf.fit(df_train_s, df_train_y)
    train_accuracy.append(rf.score(df_train_s, df_train_y))
    test_accuracy.append(rf.score(df_test_s, df_test_y))
    
    
df_score_leaf = pd.DataFrame({'MinLeafSize': para_leaf,
                             'TrainScore': train_accuracy,
                             'TestScore': test_accuracy})


plt.plot(para_leaf, train_accuracy, linestyle='-', label="Train Accuracy")
plt.plot(para_leaf, test_accuracy, linestyle='--', label="Test Accuracy")
plt.legend()
df_score_leaf.round(3)
# Out:
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   if sys.path[0] == '':
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   if sys.path[0] == '':
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   if sys.path[0] == '':
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   if sys.path[0] == '':
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   if sys.path[0] == '':
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   if sys.path[0] == '':
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   if sys.path[0] == '':
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   if sys.path[0] == '':
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   if sys.path[0] == '':
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   if sys.path[0] == '':
#    MinLeafSize  TrainScore  TestScore
# 0           10       0.961      0.960
# 1           20       0.959      0.958
# 2           30       0.959      0.958
# 3           40       0.958      0.957
# 4           50       0.958      0.957
# 5           60       0.958      0.957
# 6           70       0.958      0.957
# 7           80       0.958      0.957
# 8           90       0.958      0.957
# 9          100       0.958      0.957

# %%
rf_final = RFC(n_estimators = 60,
               max_depth = 20)
rf_final.fit(df_train_s, df_train_y)
# Out:
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   This is separate from the ipykernel package so we can avoid doing imports until
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=20, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=60,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
y_pred = rf_final.predict(df_test_s)
print('Accuracy: {0:.3f}\n'.format(accuracy_score(df_test_y, y_pred)))
print('Confusion Mat:\n{}'.format(confusion_matrix(df_test_y, y_pred)))
# Out:
# Accuracy: 0.962
#
# Confusion Mat:
# [[   84   550]
#  [   23 14237]]

# %%
df_importance = pd.DataFrame()
df_importance['Feature'] = v_feature_short
df_importance['Importance'] = rf_final.feature_importances_ # TREECLASS.feature_importances_

df_importance.sort_values('Importance', ascending=False, inplace=True)
df_importance.round(3)
# Out:
#                   Feature  Importance
# 1   customerType_PERSONAL       0.095
# 31         channelType_총판       0.049
# 3                 age_40대       0.038
# 12            payment_CMS       0.036
# 6          marital_SINGLE       0.035
# 50         maxDay_str_토요일       0.034
# 11          credit_MIDDLE       0.033
# 2                 age_30대       0.030
# 0             gender_MALE       0.030
# 9     residence_OFFICETEL       0.030
# 49         maxDay_str_일요일       0.028
# 8         residence_HOUSE       0.027
# 52       maxGift_str_지급 X       0.027
# 4                 age_50대       0.024
# 15           province_서울시       0.023
# 20         provinceIS_서울시       0.023
# 19         provinceIS_부산시       0.021
# 14           province_부산시       0.021
# 41        cityGradeIS_2급지       0.021
# 48         maxDay_str_월요일       0.018
# 51         maxDay_str_화요일       0.017
# 23          cityGrade_2급지       0.017
# 13           province_경상도       0.016
# 18         provinceIS_경상도       0.016
# 17           province_충청도       0.015
# 10             credit_LOW       0.015
# 46         maxDay_str_목요일       0.015
# 29        channelType_양판점       0.015
# 47         maxDay_str_수요일       0.014
# 22         provinceIS_충청도       0.014
# 28        channelType_쇼핑몰       0.014
# 5              age_60대 이상       0.013
# 7          residence_ETC.       0.012
# 38       contractType_1_H       0.011
# 24          cityGrade_3급지       0.011
# 42        cityGradeIS_3급지       0.010
# 30         channelType_연장       0.009
# 32    contractExtended_연장       0.009
# 40       contractType_2_M       0.009
# 25          cityGrade_4급지       0.008
# 39       contractType_1_M       0.008
# 44        cityGradeIS_5급지       0.008
# 43        cityGradeIS_4급지       0.008
# 37       contractType_MMQ       0.007
# 26          cityGrade_5급지       0.007
# 16           province_전라도       0.007
# 36       contractType_MIQ       0.007
# 21         provinceIS_전라도       0.007
# 35       contractType_HMQ       0.007
# 33       contractType_EMQ       0.006
# 34       contractType_HIQ       0.005
# 27          cityGrade_6급지       0.004
# 45        cityGradeIS_6급지       0.004
# 55         overDue_str_3일       0.004
# 56         overDue_str_4일       0.003
# 54         overDue_str_2일       0.003
# 53         overDue_str_1일       0.003

# %%
df_importance.sort_values('Importance', ascending=True, inplace=True)
coordinates=range(len(df_importance))
plt.figure(figsize=(10,20))

plt.barh(y=coordinates, width=df_importance['Importance'])
plt.yticks(coordinates, df_importance['Feature'])
plt.xlabel('변수 중요도')
plt.ylabel('변수')
# Out:
# Text(0, 0.5, '변수')

# %% [markdown]
# # GBC

# %%
gb_uncustomized = GBC()
gb_uncustomized.fit(df_train_s, df_train_y)
# Out:
# /home/pirl/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/gradient_boosting.py:1450: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GradientBoostingClassifier(criterion='friedman_mse', init=None,
#                            learning_rate=0.1, loss='deviance', max_depth=3,
#                            max_features=None, max_leaf_nodes=None,
#                            min_impurity_decrease=0.0, min_impurity_split=None,
#                            min_samples_leaf=1, min_samples_split=2,
#                            min_weight_fraction_leaf=0.0, n_estimators=100,
#                            n_iter_no_change=None, presort='auto',
#                            random_state=None, subsample=1.0, tol=0.0001,
#                            validation_fraction=0.1, verbose=0,
#                            warm_start=False)

# %%
print('Accuracy on Training: {0:.3f}\n'.format(gb_uncustomized.score(df_train_s, df_train_y)))
print('Accuracy on Test: {0:.3f}\n'.format(gb_uncustomized.score(df_test_s, df_test_y)))
# Out:
# Accuracy on Training: 0.961
#
# Accuracy on Test: 0.960

# %%
params = {'learning_rate':'',
          'max_depth':'',
          'min_samples_leaf':'',
          'min_samples_split':'',
          'n_estimators':''}

# %% [markdown]
# ### Learning Rate

# %%
# Train/Test Score 저장할 list
train_accuracy = []; test_accuracy = []

# max_depth
para_lrate = [lrate/10 for lrate in range(1, 11)]


for v_lrate in para_lrate:
    gb = GBC(learning_rate = v_lrate)
    gb.fit(df_train_s, df_train_y)
    train_accuracy.append(gb.score(df_train_s, df_train_y))
    test_accuracy.append(gb.score(df_test_s, df_test_y))
    
    
df_score_lrate = pd.DataFrame({'L_Rate': para_lrate,
                             'TrainScore': train_accuracy,
                             'TestScore': test_accuracy})

plt.plot(para_lrate, train_accuracy, linestyle='-', label="Train Score")
plt.plot(para_lrate, test_accuracy, linestyle='--', label="Test Score")
plt.legend()

df_score_lrate.sort_values('TestScore', ascending = False).round(3)
# Out:
# /home/pirl/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/gradient_boosting.py:1450: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/pirl/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/gradient_boosting.py:1450: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/pirl/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/gradient_boosting.py:1450: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/pirl/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/gradient_boosting.py:1450: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/pirl/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/gradient_boosting.py:1450: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/pirl/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/gradient_boosting.py:1450: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/pirl/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/gradient_boosting.py:1450: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/pirl/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/gradient_boosting.py:1450: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/pirl/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/gradient_boosting.py:1450: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/pirl/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/gradient_boosting.py:1450: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#    L_Rate  TrainScore  TestScore
# 3     0.4       0.965      0.961
# 8     0.9       0.960      0.961
# 4     0.5       0.966      0.961
# 1     0.2       0.963      0.960
# 2     0.3       0.964      0.960
# 7     0.8       0.962      0.960
# 6     0.7       0.962      0.960
# 5     0.6       0.962      0.960
# 0     0.1       0.961      0.960
# 9     1.0       0.957      0.958

# %% [markdown]
# #### LR = 0.5

# %%
params['learning_rate'] = 0.5

# %% [markdown]
# ### 숲의 나무의 수

# %%
# Train/Test Score 저장할 list
train_accuracy = []; test_accuracy = []

# max_depth
para_ntree = [ntree*10 for ntree in range(1, 16)]


for v_max_ntree in para_ntree:
    gb = GBC(learning_rate = params['learning_rate'],
             n_estimators = v_max_ntree)
    gb.fit(df_train_s, df_train_y)
    train_accuracy.append(gb.score(df_train_s, df_train_y))
    test_accuracy.append(gb.score(df_test_s, df_test_y))
    
    
df_score_ntree = pd.DataFrame({'N_Tree': para_ntree,
                             'TrainScore': train_accuracy,
                             'TestScore': test_accuracy})

plt.plot(para_ntree, train_accuracy, linestyle='-', label="Train Score")
plt.plot(para_ntree, test_accuracy, linestyle='--', label="Test Score")
plt.legend()

df_score_ntree.round(6)
# Out:
# /home/pirl/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/gradient_boosting.py:1450: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/pirl/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/gradient_boosting.py:1450: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/pirl/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/gradient_boosting.py:1450: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/pirl/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/gradient_boosting.py:1450: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/pirl/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/gradient_boosting.py:1450: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/pirl/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/gradient_boosting.py:1450: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/pirl/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/gradient_boosting.py:1450: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/pirl/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/gradient_boosting.py:1450: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/pirl/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/gradient_boosting.py:1450: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/pirl/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/gradient_boosting.py:1450: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/pirl/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/gradient_boosting.py:1450: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/pirl/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/gradient_boosting.py:1450: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/pirl/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/gradient_boosting.py:1450: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/pirl/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/gradient_boosting.py:1450: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/pirl/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/gradient_boosting.py:1450: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#     N_Tree  TrainScore  TestScore
# 0       10       0.961      0.959
# 1       20       0.962      0.960
# 2       30       0.963      0.961
# 3       40       0.963      0.961
# 4       50       0.964      0.961
# 5       60       0.964      0.961
# 6       70       0.965      0.961
# 7       80       0.965      0.961
# 8       90       0.966      0.961
# 9      100       0.966      0.961
# 10     110       0.966      0.960
# 11     120       0.967      0.960
# 12     130       0.967      0.960
# 13     140       0.967      0.960
# 14     150       0.967      0.960

# %%
## n_estimators = 40
params['n_estimators'] = 40

# %%
# Train/Test Score 저장할 list
train_accuracy = []; test_accuracy = []

# max_depth
para_depth = [depth for depth in range(20, 31)]


for v_max_depth in para_depth:
    gb = GBC(learning_rate = params['learning_rate'],
             n_estimators = params['n_estimators'],
             max_depth = v_max_depth)
    gb.fit(df_train_s, df_train_y)
    train_accuracy.append(gb.score(df_train_s, df_train_y))
    test_accuracy.append(gb.score(df_test_s, df_test_y))
    
    
df_score_depth = pd.DataFrame({'Depth': para_depth,
                             'TrainScore': train_accuracy,
                             'TestScore': test_accuracy})

plt.plot(para_depth, train_accuracy, linestyle='-', label="Train Score")
plt.plot(para_depth, test_accuracy, linestyle='--', label="Test Score")
plt.legend()
# Out:
# /home/pirl/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/gradient_boosting.py:1450: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/pirl/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/gradient_boosting.py:1450: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/pirl/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/gradient_boosting.py:1450: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/pirl/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/gradient_boosting.py:1450: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/pirl/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/gradient_boosting.py:1450: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/pirl/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/gradient_boosting.py:1450: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/pirl/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/gradient_boosting.py:1450: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/pirl/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/gradient_boosting.py:1450: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/pirl/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/gradient_boosting.py:1450: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/pirl/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/gradient_boosting.py:1450: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/pirl/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/gradient_boosting.py:1450: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
df_score_depth.sort_values('TestScore', ascending = False).round(3)
# Out:
#     Depth  TrainScore  TestScore
# 1      21       0.999      0.946
# 0      20       0.999      0.945
# 3      23       0.999      0.945
# 5      25       0.999      0.945
# 7      27       0.999      0.945
# 8      28       0.999      0.944
# 10     30       0.999      0.944
# 9      29       0.999      0.943
# 4      24       0.999      0.943
# 2      22       0.999      0.943
# 6      26       0.999      0.943

# %%
## max_depth
params['max_depth'] = 21

# %%
# Train/Test Score 저장할 list
train_accuracy = []; test_accuracy = []

# max_depth
para_leaf = [leaf*10 for leaf in range(20, 31)]


for v_leaf in para_leaf:
    gb = GBC(learning_rate = params['learning_rate'],
             n_estimators = params['n_estimators'],
             max_depth = params['max_depth'],
             min_samples_leaf = v_leaf)
    gb.fit(df_train_s, df_train_y)
    train_accuracy.append(gb.score(df_train_s, df_train_y))
    test_accuracy.append(gb.score(df_test_s, df_test_y))
    
    
df_score_leaf = pd.DataFrame({'MinleafSize': para_leaf,
                             'TrainScore': train_accuracy,
                             'TestScore': test_accuracy})


plt.plot(para_leaf, train_accuracy, linestyle='-', label="Train Score")
plt.plot(para_leaf, test_accuracy, linestyle='--', label="Test Score")
plt.legend()
# Out:
# /home/pirl/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/gradient_boosting.py:1450: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/pirl/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/gradient_boosting.py:1450: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/pirl/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/gradient_boosting.py:1450: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/pirl/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/gradient_boosting.py:1450: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/pirl/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/gradient_boosting.py:1450: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/pirl/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/gradient_boosting.py:1450: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/pirl/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/gradient_boosting.py:1450: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/pirl/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/gradient_boosting.py:1450: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/pirl/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/gradient_boosting.py:1450: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/pirl/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/gradient_boosting.py:1450: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/pirl/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/gradient_boosting.py:1450: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
df_score_leaf.sort_values('TestScore', ascending = False).round(6)
# Out:
#     MinleafSize  TrainScore  TestScore
# 6           260    0.974015   0.962468
# 7           270    0.973555   0.962267
# 1           210    0.975224   0.962200
# 4           240    0.974591   0.961662
# 9           290    0.973296   0.961595
# 0           200    0.976634   0.961461
# 8           280    0.973411   0.961394
# 5           250    0.974648   0.961192
# 2           220    0.975483   0.960991
# 10          300    0.973583   0.960857
# 3           230    0.974245   0.960252

# %%
## max_depth
params['min_samples_leaf'] = 260

# %% [markdown]
# ### 분리 노드 최소 크기

# %%
# Train/Test Score 저장할 list
train_accuracy = []; test_accuracy = []

# max_depth
para_split = [split*20 for split in range(20, 31)]


for v_split in para_split:
    gb = GBC(learning_rate = params['learning_rate'],
             n_estimators = params['n_estimators'],
             max_depth = params['max_depth'],
             min_samples_leaf = params['min_samples_leaf'],
             min_samples_split = v_split)
    gb.fit(df_train_s, df_train_y)
    train_accuracy.append(gb.score(df_train_s, df_train_y))
    test_accuracy.append(gb.score(df_test_s, df_test_y))
    
    
df_score_split = pd.DataFrame({'MinsplitSize': para_split,
                             'TrainScore': train_accuracy,
                             'TestScore': test_accuracy})


plt.plot(para_split, train_accuracy, linestyle='-', label="Train Accuracy")
plt.plot(para_split, test_accuracy, linestyle='--', label="Test Accuracy")
plt.legend()
# Out:
# /home/pirl/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/gradient_boosting.py:1450: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/pirl/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/gradient_boosting.py:1450: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/pirl/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/gradient_boosting.py:1450: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/pirl/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/gradient_boosting.py:1450: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/pirl/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/gradient_boosting.py:1450: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/pirl/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/gradient_boosting.py:1450: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/pirl/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/gradient_boosting.py:1450: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/pirl/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/gradient_boosting.py:1450: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/pirl/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/gradient_boosting.py:1450: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/pirl/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/gradient_boosting.py:1450: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/pirl/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/gradient_boosting.py:1450: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
df_score_split.round(6)
# Out:
#     MinsplitSize  TrainScore  TestScore
# 0            400    0.974015   0.962468
# 1            420    0.974015   0.962468
# 2            440    0.974015   0.962468
# 3            460    0.974015   0.962468
# 4            480    0.974015   0.962468
# 5            500    0.974015   0.962468
# 6            520    0.974015   0.962468
# 7            540    0.974274   0.961528
# 8            560    0.973900   0.961192
# 9            580    0.973612   0.960588
# 10           600    0.973958   0.961797

# %%
params['min_samples_split'] = 400

# %% [markdown]
# ### 최종 모형

# %%
gb_final = GBC(learning_rate = params['learning_rate'],
               n_estimators = params['n_estimators'],
               max_depth = params['max_depth'],
               min_samples_leaf = params['min_samples_leaf'],
               min_samples_split = params['min_samples_split'])
gb_final.fit(df_train_s, df_train_y)
# Out:
# /home/pirl/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/gradient_boosting.py:1450: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GradientBoostingClassifier(criterion='friedman_mse', init=None,
#                            learning_rate=0.5, loss='deviance', max_depth=21,
#                            max_features=None, max_leaf_nodes=None,
#                            min_impurity_decrease=0.0, min_impurity_split=None,
#                            min_samples_leaf=260, min_samples_split=400,
#                            min_weight_fraction_leaf=0.0, n_estimators=40,
#                            n_iter_no_change=None, presort='auto',
#                            random_state=None, subsample=1.0, tol=0.0001,
#                            validation_fraction=0.1, verbose=0,
#                            warm_start=False)

# %%
train_final = gb_final.score(df_train_s, df_train_y)
test_final = gb_final.score(df_test_s, df_test_y)
print('TrainScore: {:.3f}\nTestScore: {:.3f}'.format(train_final, test_final))
# Out:
# TrainScore: 0.974
# TestScore: 0.962

# %%
y_pred = gb_final.predict(df_test_s)
print('Accuracy: {0:.3f}\n'.format(accuracy_score(df_test_y, y_pred)))
print('Confusion Mat:\n{}'.format(confusion_matrix(df_test_y, y_pred)))
# Out:
# Accuracy: 0.962
#
# Confusion Mat:
# [[  158   476]
#  [   83 14177]]

# %%
df_importance = pd.DataFrame()
df_importance['Feature'] = v_feature_short
df_importance['Importance'] = gb_final.feature_importances_ # TREECLASS.feature_importances_

df_importance.sort_values('Importance', ascending=False, inplace=True)
df_importance.round(3)
# Out:
#                   Feature  Importance
# 1   customerType_PERSONAL       0.186
# 49         maxDay_str_일요일       0.162
# 31         channelType_총판       0.157
# 50         maxDay_str_토요일       0.151
# 2                 age_30대       0.068
# 38       contractType_1_H       0.047
# 3                 age_40대       0.045
# 12            payment_CMS       0.013
# 6          marital_SINGLE       0.013
# 39       contractType_1_M       0.012
# 11          credit_MIDDLE       0.011
# 8         residence_HOUSE       0.010
# 40       contractType_2_M       0.007
# 36       contractType_MIQ       0.007
# 9     residence_OFFICETEL       0.007
# 0             gender_MALE       0.007
# 37       contractType_MMQ       0.006
# 23          cityGrade_2급지       0.006
# 52       maxGift_str_지급 X       0.005
# 19         provinceIS_부산시       0.005
# 4                 age_50대       0.005
# 20         provinceIS_서울시       0.005
# 15           province_서울시       0.005
# 14           province_부산시       0.005
# 32    contractExtended_연장       0.004
# 29        channelType_양판점       0.004
# 30         channelType_연장       0.004
# 35       contractType_HMQ       0.004
# 28        channelType_쇼핑몰       0.004
# 41        cityGradeIS_2급지       0.004
# 17           province_충청도       0.004
# 5              age_60대 이상       0.003
# 22         provinceIS_충청도       0.002
# 48         maxDay_str_월요일       0.002
# 13           province_경상도       0.002
# 51         maxDay_str_화요일       0.002
# 42        cityGradeIS_3급지       0.002
# 25          cityGrade_4급지       0.002
# 33       contractType_EMQ       0.001
# 10             credit_LOW       0.001
# 24          cityGrade_3급지       0.001
# 26          cityGrade_5급지       0.001
# 18         provinceIS_경상도       0.001
# 46         maxDay_str_목요일       0.001
# 47         maxDay_str_수요일       0.001
# 44        cityGradeIS_5급지       0.001
# 43        cityGradeIS_4급지       0.001
# 27          cityGrade_6급지       0.001
# 34       contractType_HIQ       0.001
# 21         provinceIS_전라도       0.001
# 45        cityGradeIS_6급지       0.000
# 16           province_전라도       0.000
# 7          residence_ETC.       0.000
# 53         overDue_str_1일       0.000
# 54         overDue_str_2일       0.000
# 55         overDue_str_3일       0.000
# 56         overDue_str_4일       0.000

# %%
df_importance.sort_values('Importance', ascending=True, inplace=True)
coordinates=range(len(df_importance))

# 변수중요도 차트
plt.figure(figsize=(10,20))
plt.barh(y=coordinates, width=df_importance['Importance'])
plt.yticks(coordinates, df_importance['Feature'])
plt.xlabel('변수 중요도')
plt.ylabel('변수')
# Out:
# Text(0, 0.5, '변수')
